# %%
df = spark.read.table("silver.grocery_silver")

# %%
from pyspark.sql.functions import *

agg_df = df.groupBy("Catagory").agg(sum("Sales_Volume").alias("Total_Sales"))
display(agg_df)

# %%
agg_df.write.format("delta").mode("append").saveAsTable("gold.grocery_gold")
